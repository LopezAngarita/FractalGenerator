# %% [markdown]
# # Plot some cool fractals!

# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from fractal_generator.fractal_generator import FractalGenerator, FractalType
import numpy as np

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Julia Fractals

# %%
_ = FractalGenerator(n=300, xlim=(-2, 2), ylim=(-2, 2), thr=2, max_iter=10).create_julia(complex_function=lambda z: np.sin(z** 4 + 1.41 + 3)*np.exp((2.5+0)*1.J)).plot()

# %%
_ = FractalGenerator().create_julia().plot()

# %% [markdown]
# ## Mandelbrot Fractals

# %%
_ = FractalGenerator(n=300, xlim=(-2, 0.5), ylim=(-1, 1), thr=2, max_iter=10).create_mandelbrot().plot()

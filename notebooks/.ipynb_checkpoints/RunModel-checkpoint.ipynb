# %% [markdown]
# # Create training data with 50K fractal images

# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from fractalGAN.fractal_generator import FractalGenerator, FractalType
import numpy as np

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Generate a Sample

# %%
FractalGenerator(type_=FractalType.Julia).create_mandelbrot(n=300, xlim=(-2, 0.5), ylim=(-1, 1), thr=2, max_iter=10).plot()

# %%
FractalGenerator(type_=FractalType.Julia).create_julia(complex_function=lambda z: np.sin(z ** 4 + 1.41), n=300, xlim=(-2, 2), ylim=(-2, 2), thr=2, max_iter=10).plot()

# %% [markdown]
# ## Generate Dataset

# %%
from fractalGAN.fractal_training_validation_set import FractalTrainingValidationSet
import time
start_time = time.time()
FractalTrainingValidationSet(n_examples=10000, directory='/home/gabriel_lopez/stylegan2/dataset2/').generate_examples()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /home/gabriel_lopez/research_projects/FractalGAN/fractalGAN/fractal_generator.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "png" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(str(Path(container) / filename), png='png', dpi=100)
# --- 3666.569480895996 seconds ---
